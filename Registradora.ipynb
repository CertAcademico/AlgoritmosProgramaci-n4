# %% [markdown]
# # **Programa de Facturación**

# %% [markdown]
# Esta parte del codigo fue consultada y adaptada de la pagina
# [Fácil de limpiar](https://facildelimpiar.com/limpiar-pantalla-en-python-guia-rapida/)
#
#
# Primeramente, importamos el modulo **os**.
#
# ![image.png](data:image/png;base64,...)
#
# Este tiene varias funciones, en este caso la funcion que nos interesa, identifica que sistema operativo estamos usando.
#
#
# ---
#
#
# Aqui definimos una funcion que identifique el sistema operativo utilizado, definimos una funcion para poder utilizarla las veces que sean necesarias y poder optimizar el codigo.
#
# ![image.png](data:image/png;base64,...)
#
# En este caso, con **os.system** sabemos si es Windows o otro sistema operativo; Windows se identifica con las siglas **nt** y si es este sistema operativo, se ejecuta el codigo **cls**, el cual quita de la pantalla los datos anteriormente mostrados al usuario.
#
# Si es otro sistema operativo se ejecuta el codigo **clear**, el cual realiza la misma funcion que **cls** pero en otros sistemas operativos.
#
#
#
# ---

# %% [markdown]
# Usamos la funcion lista para poder guardar los datos solicitados por el usuario y a esa funcion le damos como nombre de variable **Productos**.
#
# ![image.png](data:image/png;base64,...)
#
# Se utiliza para poder almacenar el nombre y precio de los productos que el usuario va a ingresar posteriormente.
#
# -----------------
#
# Ahora definimos la variable **Precio_propina** para indicar el valor de la propina y lo igualamos a cero para que no genere error.
#
# ![Screenshot_1.png](data:image/png;base64,...)
#
# Al momento de dar valores numericos como vemos en este caso se iguala a cero para que este pueda realizar de manera correcta la operacion o genere un resultado valido pero cuando no se pone un cero este no arrojara un valor erroneo.
#
# ------------
#
# Definimos la variable **Propina** para poder almacenar el porcentaje de propina que el usuario desea o no agregar y la igualamos a cero.
#
# ![Propina.png](data:image/png;base64,...)
#
# Como se comento anteriormente igualamos a cero para que este genere un valor valido.
#
# ---------------
#
# Para dar inicio al programa le generamos un titulo para indicar que es el programa o a donde va orientado este.
#
# ![Print generador de facturas.png](data:image/png;base64,...)
#
# Usamos la funcion print para que imprima el texto deseado ya sea un mensaje o un resultado de algun operacion.
#
# ------------
#
# Ahora definimos la variable **Num_Fact** para indicar el numero de la factura a realizar, aqui se guardara el numero de factura que digite el usuario.
#
# ![NumFact.png](data:image/png;base64,...)
#
# Aqui utilizamos dos tipos de funciones: Int e Input.
#
# Primero daremos la explicacion de **Int**, esta es una funcion tipo entero donde da el ingreso a datos numerimos que no sean decimales, esto valores pueden ser positivos o negativos.
#
# Luego tenemos a **Input** donde se usa para dar la posibilidad de introducir texto o cadenas de texto que el usuario desea agregar.
#
# ------------
#
# Definimos la variable **Fecha** para indicar la fecha en la que se realizo la factura
#
# ![Fecha factura.png](data:image/png;base64,...)
#
# Como en el caso anterior pero sin usar int ya que como necesitamos los slash(/) siendo estos datos no numeros y esto daria error si usamos int porque este solo permite numeros enteros.
#
# Despues de definir la variable **Fecha** ponemos igual input para dar entrada a una cadena de texto donde pondremos el **(Dia/Mes/Año)**.
#
# --------------
#
# Definimos la variable **Nombre_Cliente** para pedirle al usuario y/o cliente su nombre
#
# ![Nombre Cliente.png](data:image/png;base64,...)
#
# En este caso y como el anterior solo usaremos la funcion input donde primero ponemos la varible **Nombre_Cliente** igual a input porque vamos a introducir una cadena de texto **Nombre Del Cliente:**.
#
# ---

# %% [markdown]
# Para poder pedir los productos al usuario debemos utilizar un ciclo **while**.
#
# ![image.png](data:image/png;base64,...)
#
# Esto lo hacemos para que el usuario pueda añadir todos los productos que necesite agregar.
#
# ---
#
# Posteriormente, agregamos en la variable **Nombre_producto** los productos que el usuario desea adjuntar en la factura.
#
# ![image.png](data:image/png;base64,...)
#
# Si el usuario no desea gregar ningun producto o ya no necesita agregar mas productos, debe digitar la palabra **salir**.
#
# ---
#
# Establecemos un **if** en el cual se evaluan los datos que digite el usuario
# a la hora de preguntar el producto a agregar.
#
# ![image.png](data:image/png;base64,...)
#
# Evaluamos si en la variable **Nombre_producto** se encuentra guardada la palabra **salir**; si esto es así, se rompe el cilo while con la instrucción **break**.
#
# ---
#
# Ponemos la instrucción **try** para que le consulte al usuario cual es el precio del producto digitado anteriormente.
#
# ![image.png](data:image/png;base64,...)
#
# Ponemos la clase **float** para poder recibir el precio en forma de numeros con decimales y lo guardamos en la variable **Precio_producto**.
#
# ---
#
# Utilizamos **except ValueError** en caso de que el usuario digite letras o simbolos en el precio del producto.
#
# ![image.png](data:image/png;base64,...)
#
# Si este caso se presenta, se le mostraria al usuario el mensaje de precio invalido y con la instrucción **continue** seguimos preguntando el precio hasta que el usuario digite un numero ya sea entero o decimal.
#
# ---
#
# Finalmente, cuando el usuario digite el nombre del producto y el precio del producto se ejecutara el metodo **append**; este se encarga de agregar a la lista previamente creada los valores digitados por el usuario.
#
# ![image.png](data:image/png;base64,...)
#
# Con esto agregariamos los adtos ingresados tanto en la variable **Nombre_producto**, como en la variable **Precio Producto** y esto se ejecutaria cada vez que el usuario quiera agregar un producto nuevo.
#
# ---

# %% [markdown]
# Utilizamos el metodo **sum** para sumar los precios de los productos ingresados.
#
# ![image.png](data:image/png;base64,...)
#
# con **for _,** separamos unicamente el valor que necesitamos, en este caso el **precio**, este valor lo consultamos en la lista **Productos** que se definio al principio del codigo y el resultado de la suma la guardamos en la variable **Precio_Total**.

# %% [markdown]
# Tambien debemos utilizar un **while** a la hora de preguntarle a usuario si desea agregar propina a la compra.
#
# ![image.png](data:image/png;base64,...)
#
# Esto se hace en caso de que el usuario digite un dato erroneo, si este es el caso en vez de "romper" el codigo, este le vuelve a preguntar si desea o no agregar propina.
#
# ---
#
# Posteriormente ponemos la instrucción **try** para que le consulte al usuario por medio de un **input** si desea o no agregar propina, Si el usuario digita el numero "1" se agregara propina y si se digita el numero "2" no se agregara propina.
#
# ![image.png](data:image/png;base64,...)
#
# Por medio de un **int** establecemos que solo se puedan recibir numeros enteros,evitando que el usuario digite letas, simbolos o numeros decimales. El resultado que se digite se guardara en la variable **Opcion1**.
#
# ---
#
# Utilizamos **except ValueError** en caso de que el usuario digite letras o simbolos en el precio del producto.
#
# ![image.png](data:image/png;base64,...)
#
# Si este caso se presenta, se le mostraria al usuario el mensaje de valor invalido y con la instrucción **continue** seguimos preguntando si el usuario desea o no agregar propina.
#
# ---
#
# Utilizamos un **if** en el cual evaluaremos el dato registrado en la variable **Opcion1**.
#
# ![image.png](data:image/png;base64,...)
#
# Este **if** solo se ejecutara si el dato ingresado fue el numero 1.
#
# ---
#
# Dentro del **if** utilizaremos un ciclo **while** en caso de que el usuario digite valores invalidos no generar ningun error en laejecucion del codigo.
#
# ![image.png](data:image/png;base64,...)
#
# Gracias a esto le podremos seguir preguntando al usuario cual es el prcentaje de propina que desea agregar en acso de presentar algun error.
#
# ---
#
# Primeramente, dentro de un **try** debemos mostrarle al usuario por medio de la función **print** cual es el porcentaje maximo de propina que permite la ley colombiana 1935 del 2018, la cual es del 10%.
#
# ![image.png](data:image/png;base64,...)
#
# El dato registrado por el usuario sera guardado en la variable **Propina**, los datos permitidos son numeros enteros y decimales gracias a la clase **float**.
#
# ---
#
# Utilizamos **except ValueError** en caso de que el usuario digite letras o simbolos en la propina a agregar.
#
# ![image.png](data:image/png;base64,...)
#
# Si este caso se presenta, se le mostraria al usuario el mensaje de valor invalido y con la instrucción **continue** seguimos preguntando cual es el valor de la propina que desea agregar.
#
# ---
#
# Con un **if** evaluamos el dato registrado en la variable **Propina**.
#
# ![image.png](data:image/png;base64,...)
#
# Si el dato registrado en esta variable es igual o menor a 10, con la instrucción **break** rompemos el ciclo **while** que le pregunta al usuario la cantidad de propina que desea agregar.
#
# ---
#
# Ponemos un **else** en caso de que el usuario digite un numero mayor a 10 o menor a 0.
#
# ![image.png](data:image/png;base64,...)
#
# Aqui solo le informamos al usuario que el valor ingresado es invalido y le recordamos en porcentaje maximo de propina que permite la ley.
#
# ---
#
# Una vez el usuario digito un porcentaje valido, se realizara un calculo el cual guardara la cantidad propina que se agregara a la factura en forma de pesos colombianos.
#
# ![image.png](data:image/png;base64,...)
#
# Una vez calculado el precio de la propina, lo guardamos en la variable **Precio_Propina** y con la instrucción **break** rompemos el cilo que le pregunta al usuario si desea o no agregar propina.
#
# ---
#
# Si recordamos, anteriormente utilizamos un **if** en caso de que el usuario desea agregar propina; ahora utilizaremos un **elif** en el cual evaluaremos el dato registrado en la variable **Opcion1**; si este numero digitado es el "2", no se le agregara propina.
#
# ![image.png](data:image/png;base64,...)
#
# Con la instruccion **break** romperemos el ciclo que le pregunta al usuario si desea o no agregar propina.
#
# ---
#
# Finalmente, si el usuario digita un dato diferente a 1 o 2 se ejecutara un **else**.
#
# ![image.png](data:image/png;base64,...)
#
# En este se le mostrara el mensaje de opcion invalido y se le volvera a preguntar si se desea o no aregar propina.
#
# ---

# %% [markdown]
# Ahora calcularemos el precio final de la compra de los productos
#
# ![Screenshot_2.png](data:image/png;base64,...)
#
# Aqui definimos la variable "**Precio_Final**" igual a "**Precio_Total**" que representa la suma total de los productos seleccionados por el cliente mas el valor de la propina definida como "**Precio_Propina**", cabe mencionar que la ultima variable no sera contada si el cliente no desea agregar propina y solo dara el valor total de los productos.
#
# ----------
#
# Por ultimo usamos la funcion "**terminal_limpia()**"
#
# ![Screenshot_3.png](data:image/png;base64,...)
#
# La utilizamos para poder limpiar los datos pero se conservan para poder generar la factura del cliente
#
# ----------
#
# Ahora vamos a imprimir los datos para generar la factura
#
# ![Screenshot_4.png](data:image/png;base64,...)
#
# Haremos un modelo de factura utilizando **print** donde mostraremos el numero de la factura, la fecha donde se genero, el nombre del cliente y la lista de los productos (Mas adelante se detallara la lista de productos), esto generado mediante las variables ya mecionadas anteriormente.
#
# -------------
#
# Siguiente a eso vamos a dar la lista de los productos con su respectivo valor usando la funcion "**For**"
#
# ![Screenshot_5.png](data:image/png;base64,...)
#
# Usaremos el **for** para que imprima la lista de los productos, primero ponemos el **for** para que itere cada producto de la lista, continuando con las variables "**Producto, Precio**" usando luego de esto **in** y la variable **Productos** que es donde sale la lista de los productos.
#
# Luego usamos **print** para imprimir la siguiente operacion (" ",Producto,": COP",Precio) donde se mostrara el nombre del producto seguido del valor de este dado en la moneda nacional (En este caso peso colombiano).
#
# ---------------
#
# Para finalizar imprimimos la lista de los productos con el valor total incluido y el valor generado por la propina (En el caso si se agrego propina)
#
# ![Screenshot_6.png](data:image/png;base64,...)
#
# Aqui se mostrar el valor total de los productos dados por la variable "**Precio_Total**", luego se mostrar el valor de la propina "**Propina**" dada en porcentaje y cuanto es el valor de la propina "**Precio_Propina**" y despues de eso el precio final con la propina agregada al valor final "**Precio_Final**" (No olvidemos que si se agrego propina se realizara la suma pero si no, dara el valor total de solo los productos).
